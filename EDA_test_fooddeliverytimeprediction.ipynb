# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("Food_Delivery.csv")
df
# Out:
#      Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0         522         7.93   Windy           Low   Afternoon      Scooter
# 1         738        16.42   Clear        Medium     Evening         Bike
# 2         741         9.52   Foggy           Low       Night      Scooter
# 3         661         7.44   Rainy        Medium   Afternoon      Scooter
# 4         412        19.03   Clear           Low     Morning         Bike
# ..        ...          ...     ...           ...         ...          ...
# 995       107         8.50   Clear          High     Evening          Car
# 996       271        16.28   Rainy           Low     Morning      Scooter
# 997       861        15.62   Snowy          High     Evening      Scooter
# 998       436        14.17   Clear           Low   Afternoon         Bike
# 999       103         6.63   Foggy           Low       Night      Scooter
#
#      Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order_ID                1000 non-null   int64
#  1   Distance_km             1000 non-null   float64
#  2   Weather                 970 non-null    object
#  3   Traffic_Level           970 non-null    object
#  4   Time_of_Day             970 non-null    object
#  5   Vehicle_Type            1000 non-null   object
#  6   Preparation_Time_min    1000 non-null   int64
#  7   Courier_Experience_yrs  970 non-null    float64
#  8   Delivery_Time_min       1000 non-null   int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 70.4+ KB

# %%
df.columns
# Out:
# Index(['Order_ID', 'Distance_km', 'Weather', 'Traffic_Level', 'Time_of_Day',
#        'Vehicle_Type', 'Preparation_Time_min', 'Courier_Experience_yrs',
#        'Delivery_Time_min'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Order_ID                   0
# Distance_km                0
# Weather                   30
# Traffic_Level             30
# Time_of_Day               30
# Vehicle_Type               0
# Preparation_Time_min       0
# Courier_Experience_yrs    30
# Delivery_Time_min          0
# dtype: int64

# %%
df["Courier_Experience_yrs"].unique()
# Out:
# array([ 1.,  2.,  5.,  9.,  6.,  4.,  7., nan,  3.,  8.,  0.])

# %%
df["Courier_Experience_yrs"].value_counts()
# Out:
# Courier_Experience_yrs
# 6.0    109
# 9.0    108
# 1.0    107
# 8.0    101
# 2.0     99
# 4.0     94
# 7.0     91
# 0.0     91
# 5.0     90
# 3.0     80
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0       522         7.93   Windy           Low   Afternoon      Scooter
# 1       738        16.42   Clear        Medium     Evening         Bike
# 2       741         9.52   Foggy           Low       Night      Scooter
# 3       661         7.44   Rainy        Medium   Afternoon      Scooter
# 4       412        19.03   Clear           Low     Morning         Bike
#
#    Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 0                    12                     1.0                 43
# 1                    20                     2.0                 84
# 2                    28                     1.0                 59
# 3                     5                     1.0                 37
# 4                    16                     5.0                 68

# %%
df['Courier_Experience_yrs'].mean()
# Out:
# 4.579381443298969

# %%
# replacing nan value with mean

df['Courier_Experience_yrs'].fillna(df['Courier_Experience_yrs'].mean(), inplace=True)

# %%
df['Courier_Experience_yrs'].isnull().sum()
# Out:
# 0

# %%
df["Courier_Experience_yrs"]
# Out:
# 0      1.0
# 1      2.0
# 2      1.0
# 3      1.0
# 4      5.0
#       ...
# 995    3.0
# 996    9.0
# 997    2.0
# 998    0.0
# 999    3.0
# Name: Courier_Experience_yrs, Length: 1000, dtype: float64

# %%
# mode is better bcoz its categorical feature

df['Weather'].fillna(df['Weather'].mode()[0], inplace=True)
df['Time_of_Day'].fillna(df['Time_of_Day'].mode()[0], inplace=True)
df['Traffic_Level'].fillna(df['Traffic_Level'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Order_ID                  0
# Distance_km               0
# Weather                   0
# Traffic_Level             0
# Time_of_Day               0
# Vehicle_Type              0
# Preparation_Time_min      0
# Courier_Experience_yrs    0
# Delivery_Time_min         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order_ID                1000 non-null   int64
#  1   Distance_km             1000 non-null   float64
#  2   Weather                 1000 non-null   object
#  3   Traffic_Level           1000 non-null   object
#  4   Time_of_Day             1000 non-null   object
#  5   Vehicle_Type            1000 non-null   object
#  6   Preparation_Time_min    1000 non-null   int64
#  7   Courier_Experience_yrs  1000 non-null   float64
#  8   Delivery_Time_min       1000 non-null   int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 70.4+ KB

# %%
sns.barplot(x='Vehicle_Type',y='Delivery_Time_min',data=df)
# Out:
# <Axes: xlabel='Vehicle_Type', ylabel='Delivery_Time_min'>

# %%
# Does delivery time depend on distance (Numerical vs Numerical)

sns.scatterplot(x='Distance_km', y='Delivery_Time_min',data=df)
# Out:
# <Axes: xlabel='Distance_km', ylabel='Delivery_Time_min'>

# %%
sns.boxplot(x='Traffic_Level', y='Delivery_Time_min',data=df)
# Out:
# <Axes: xlabel='Traffic_Level', ylabel='Delivery_Time_min'>

# %%
df.head()
# Out:
#    Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0       522         7.93   Windy           Low   Afternoon      Scooter
# 1       738        16.42   Clear        Medium     Evening         Bike
# 2       741         9.52   Foggy           Low       Night      Scooter
# 3       661         7.44   Rainy        Medium   Afternoon      Scooter
# 4       412        19.03   Clear           Low     Morning         Bike
#
#    Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 0                    12                     1.0                 43
# 1                    20                     2.0                 84
# 2                    28                     1.0                 59
# 3                     5                     1.0                 37
# 4                    16                     5.0                 68

# %%
# z score for detecting outliers nd removing

from scipy import stats

z = np.abs(stats.zscore(df['Delivery_Time_min']))
z
# Out:
# 0      0.622488
# 1      1.236090
# 2      0.102811
# 3      0.894475
# 4      0.510792
#          ...
# 995    0.123845
# 996    0.646785
# 997    1.100097
# 998    0.078514
# 999    0.057480
# Name: Delivery_Time_min, Length: 1000, dtype: float64

# %%
threshold_z = 2

outlier_indices = np.where(z > threshold_z)[0]
no_outliers = df.drop(outlier_indices)

# %%
no_outliers
# Out:
#      Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0         522         7.93   Windy           Low   Afternoon      Scooter
# 1         738        16.42   Clear        Medium     Evening         Bike
# 2         741         9.52   Foggy           Low       Night      Scooter
# 3         661         7.44   Rainy        Medium   Afternoon      Scooter
# 4         412        19.03   Clear           Low     Morning         Bike
# ..        ...          ...     ...           ...         ...          ...
# 995       107         8.50   Clear          High     Evening          Car
# 996       271        16.28   Rainy           Low     Morning      Scooter
# 997       861        15.62   Snowy          High     Evening      Scooter
# 998       436        14.17   Clear           Low   Afternoon         Bike
# 999       103         6.63   Foggy           Low       Night      Scooter
#
#      Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# ...

# %%
df.shape
# Out:
# (1000, 9)

# %%
no_outliers.shape
# Out:
# (965, 9)

# %%
sns.boxplot(data=no_outliers, x='Delivery_Time_min')
# Out:
# <Axes: xlabel='Delivery_Time_min'>

# %%
# dropped a column bcoz It doesn’t influence or relate to the target variable 
df.drop('Order_ID',axis=1,inplace=True)

# %%
df.describe()
# Out:
#        Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# count  1000.000000           1000.000000             1000.000000
# mean     10.059970             16.982000                4.579381
# std       5.696656              7.204553                2.870301
# min       0.590000              5.000000                0.000000
# 25%       5.105000             11.000000                2.000000
# 50%      10.190000             17.000000                4.579381
# 75%      15.017500             23.000000                7.000000
# max      19.990000             29.000000                9.000000
#
#        Delivery_Time_min
# count        1000.000000
# mean           56.732000
# std            22.070915
# min             8.000000
# 25%            41.000000
# 50%            55.500000
# 75%            71.000000
# max           153.000000

# %%
df.describe(include='object')
# Out:
#        Weather Traffic_Level Time_of_Day Vehicle_Type
# count     1000          1000        1000         1000
# unique       5             3           4            3
# top      Clear        Medium     Morning         Bike
# freq       500           420         338          503

# %%
sns.histplot(df['Delivery_Time_min'], kde=True)
# Out:
# <Axes: xlabel='Delivery_Time_min', ylabel='Count'>

# %%
# Calculated delivery speed (km per min)

df['Delivery_Speed_km_per_min'] = df['Distance_km'] / df['Delivery_Time_min']
df[['Distance_km', 'Delivery_Time_min', 'Delivery_Speed_km_per_min']].head()
# Out:
#    Distance_km  Delivery_Time_min  Delivery_Speed_km_per_min
# 0         7.93                 43                   0.184419
# 1        16.42                 84                   0.195476
# 2         9.52                 59                   0.161356
# 3         7.44                 37                   0.201081
# 4        19.03                 68                   0.279853

# %%
# # Created Is_Experienced column: 1 if experience ≥ 2 years, else 0

# df['Is_Experienced'] = df['Courier_Experience_yrs'].apply(lambda x: 1 if x >= 2 else 0)
# df[['Courier_Experience_yrs', 'Is_Experienced']].head()

# %%
df[['Weather','Traffic_Level']].groupby(['Weather','Traffic_Level']).size().reset_index(name='Count')
# Out:
#    Weather Traffic_Level  Count
# 0    Clear          High     89
# 1    Clear           Low    186
# 2    Clear        Medium    225
# 3    Foggy          High     21
# 4    Foggy           Low     47
# 5    Foggy        Medium     35
# 6    Rainy          High     44
# 7    Rainy           Low     80
# 8    Rainy        Medium     80
# 9    Snowy          High     20
# 10   Snowy           Low     44
# 11   Snowy        Medium     33
# 12   Windy          High     23
# 13   Windy           Low     26
# 14   Windy        Medium     47

# %%
# Under which conditions are deliveries slow ?
# calculated average delivery time for each group

df.groupby(['Weather', 'Traffic_Level'])['Delivery_Time_min'].mean().reset_index()
# Out:
#    Weather Traffic_Level  Delivery_Time_min
# 0    Clear          High          57.157303
# 1    Clear           Low          49.913978
# 2    Clear        Medium          54.240000
# 3    Foggy          High          67.238095
# 4    Foggy           Low          53.340426
# 5    Foggy        Medium          63.028571
# 6    Rainy          High          77.045455
# 7    Rainy           Low          55.037500
# 8    Rainy        Medium          55.062500
# 9    Snowy          High          70.900000
# 10   Snowy           Low          61.931818
# 11   Snowy        Medium          71.727273
# 12   Windy          High          63.478261
# 13   Windy           Low          51.384615
# 14   Windy        Medium          53.787234

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
le = LabelEncoder()

# Fit and transform the 'Weather' column
df['Weather_LabelEncoded'] = le.fit_transform(df['Weather'])
df[['Weather', 'Weather_LabelEncoded']].head()
# Out:
#   Weather  Weather_LabelEncoded
# 0   Windy                     4
# 1   Clear                     0
# 2   Foggy                     1
# 3   Rainy                     2
# 4   Clear                     0

# %%
df.head()
# Out:
#    Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0         7.93   Windy           Low   Afternoon      Scooter
# 1        16.42   Clear        Medium     Evening         Bike
# 2         9.52   Foggy           Low       Night      Scooter
# 3         7.44   Rainy        Medium   Afternoon      Scooter
# 4        19.03   Clear           Low     Morning         Bike
#
#    Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min  \
# 0                    12                     1.0                 43
# 1                    20                     2.0                 84
# 2                    28                     1.0                 59
# 3                     5                     1.0                 37
# 4                    16                     5.0                 68
#
#    Delivery_Speed_km_per_min  Weather_LabelEncoded
# 0                   0.184419                     4
# 1                   0.195476                     0
# ...

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.drop('Weather_LabelEncoded',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0         7.93   Windy           Low   Afternoon      Scooter
# 1        16.42   Clear        Medium     Evening         Bike
# 2         9.52   Foggy           Low       Night      Scooter
# 3         7.44   Rainy        Medium   Afternoon      Scooter
# 4        19.03   Clear           Low     Morning         Bike
#
#    Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min  \
# 0                    12                     1.0                 43
# 1                    20                     2.0                 84
# 2                    28                     1.0                 59
# 3                     5                     1.0                 37
# 4                    16                     5.0                 68
#
#    Delivery_Speed_km_per_min
# 0                   0.184419
# 1                   0.195476
# 2                   0.161356
# 3                   0.201081
# 4                   0.279853

# %%
# one hot encoding

df=pd.get_dummies(df, columns=['Weather','Time_of_Day', 'Traffic_Level','Vehicle_Type'], drop_first=True,dtype=int)

# %%
df.head()
# Out:
#    Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# 0         7.93                    12                     1.0
# 1        16.42                    20                     2.0
# 2         9.52                    28                     1.0
# 3         7.44                     5                     1.0
# 4        19.03                    16                     5.0
#
#    Delivery_Time_min  Delivery_Speed_km_per_min  Weather_Foggy  Weather_Rainy  \
# 0                 43                   0.184419              0              0
# 1                 84                   0.195476              0              0
# 2                 59                   0.161356              1              0
# 3                 37                   0.201081              0              1
# 4                 68                   0.279853              0              0
#
#    Weather_Snowy  Weather_Windy  Time_of_Day_Evening  Time_of_Day_Morning  \
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Define features (X) and target (y)

X = df.drop('Delivery_Time_min', axis=1)
y = df['Delivery_Time_min']

# %%
df.head()
# Out:
#    Distance_km  Preparation_Time_min  Courier_Experience_yrs  \
# 0         7.93                    12                     1.0
# 1        16.42                    20                     2.0
# 2         9.52                    28                     1.0
# 3         7.44                     5                     1.0
# 4        19.03                    16                     5.0
#
#    Delivery_Time_min  Delivery_Speed_km_per_min  Weather_Foggy  Weather_Rainy  \
# 0                 43                   0.184419              0              0
# 1                 84                   0.195476              0              0
# 2                 59                   0.161356              1              0
# 3                 37                   0.201081              0              1
# 4                 68                   0.279853              0              0
#
#    Weather_Snowy  Weather_Windy  Time_of_Day_Evening  Time_of_Day_Morning  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

X_train.shape , X_test.shape
# Out:
# ((700, 15), (300, 15))

# %%
X_train.corr()
# Out:
#                            Distance_km  Preparation_Time_min  \
# Distance_km                   1.000000             -0.030123
# Preparation_Time_min         -0.030123              1.000000
# Courier_Experience_yrs        0.012609             -0.053464
# Delivery_Speed_km_per_min     0.796509             -0.351081
# Weather_Foggy                -0.043136             -0.058004
# Weather_Rainy                 0.051681              0.016290
# Weather_Snowy                 0.060215              0.003316
# Weather_Windy                -0.012118             -0.016222
# Time_of_Day_Evening          -0.014925              0.060553
# Time_of_Day_Morning           0.064953             -0.039876
# Time_of_Day_Night            -0.016160              0.010964
# Traffic_Level_Low             0.012100             -0.006161
# Traffic_Level_Medium         -0.015208             -0.001916
# Vehicle_Type_Car              0.030726             -0.025479
# ...

# %%
import seaborn as sns 

# using pearson correlation (range is between -1 to +1 )
plt.figure(figsize=(12,10))
cor=X_train.corr()
sns.heatmap(cor,annot=True,cmap="YlGnBu")
plt.show()

# %%
# Calculate Pearson correlation of each feature with the target

cor_target = X_train.corrwith(y_train)
cor_target
# Out:
# Distance_km                  0.760680
# Preparation_Time_min         0.302394
# Courier_Experience_yrs      -0.082920
# Delivery_Speed_km_per_min    0.275677
# Weather_Foggy               -0.006829
# Weather_Rainy                0.095769
# Weather_Snowy                0.150439
# Weather_Windy               -0.029578
# Time_of_Day_Evening          0.037224
# Time_of_Day_Morning          0.029245
# Time_of_Day_Night           -0.030022
# Traffic_Level_Low           -0.137183
# Traffic_Level_Medium         0.010604
# Vehicle_Type_Car             0.040216
# Vehicle_Type_Scooter        -0.020224
# dtype: float64

# %%
# filtering absolute correlation with the target is less than the threshold
# Strongly correlated features with target:

threshold = 0.7
strong_corr = cor_target[cor_target.abs() > threshold]  
strong_corr
# Out:
# Distance_km    0.76068
# dtype: float64

# %%
X_train_selected = X_train[strong_corr.index]
X_train_selected
# Out:
#      Distance_km
# 541        16.30
# 440         7.67
# 482        19.41
# 422        12.74
# 778        11.62
# ..           ...
# 106        17.59
# 270         9.39
# 860        16.38
# 435        16.73
# 102         0.86
#
# [700 rows x 1 columns]
